# %% [markdown]
# ![Imagen](https://docs.google.com/uc?export=download&id=1lLylAGjuAW3qa7hjtKAn9zz00lQLMyfP)

# %% [markdown]
# <p><img alt="Colaboratory logo" height="45px" src="/img/colab_favicon.ico" align="left" hspace="10px" vspace="0px"></p>
#
# # Notebook para descargar imagenes

# %% [markdown]
# ## Paso 1: Permitimos el acceso a nuestro drive

# %%
# Cargamos nuestro drive en el notebook de trabajo
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Paso 2: Instalamos las librerias

# %%
# !sudo apt-get install chromium-chromedriver
# !pip install google_images_download
# !pip install selenium
# !git clone https://github.com/ultralytics/google-images-download
# %cd google-images-download
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   chromium-browser chromium-browser-l10n chromium-codecs-ffmpeg-extra
# Suggested packages:
#   webaccounts-chromium-extension unity-chromium-extension adobe-flashplugin
# The following NEW packages will be installed:
#   chromium-browser chromium-browser-l10n chromium-chromedriver
#   chromium-codecs-ffmpeg-extra
# 0 upgraded, 4 newly installed, 0 to remove and 13 not upgraded.
# Need to get 81.0 MB of archives.
# After this operation, 273 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-codecs-ffmpeg-extra amd64 87.0.4280.66-0ubuntu0.18.04.1 [1,122 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 chromium-browser amd64 87.0.4280.66-0ubuntu0.18.04.1 [71.7 MB]
# ...

# %% [markdown]
# ## Paso 3: Ejecutamos el script que realiza la búsqueda de imagenes (este paso se puede realizar las veces que sean necesarias)

# %%
# !python3 bing_scraper.py --search 'apple fruit green' --limit 100 --download --chromedriver /usr/lib/chromium-browser/chromedriver
# Out:
# Searching for https://www.bing.com/images/search?q=apple%20fruit%20green
# ...
# 1/100 https://debannsmith.files.wordpress.com/2014/08/green-apple-fruit-hd-wallpaper.jpg
# 2/100 http://images6.fanpop.com/image/photos/34900000/Green-Apple-fruit-34914750-1200-737.jpg
# 3/100 https://www.nextlevelcare.us/wp-content/uploads/2017/06/Green-Apple-12175856.jpg
# 4/100 https://cdn2.stylecraze.com/wp-content/uploads/2013/06/Top-26-Amazing-Benefits-Of-Green-Apples-For-Skin-Hair-And-Health-1.jpg
# 5/100 https://romanlosangelez.files.wordpress.com/2013/11/green_apples1.jpg
# 6/100 http://www.vigorous-tech.com/d/pic/3-fruit-powder/green-apple-fruit.jpg
# 7/100 http://www.chicvegan.com/wp-content/uploads/2014/11/Fresh-Green-Apple-Fruits-A.jpg
# 8/100 http://images6.fanpop.com/image/photos/34900000/Green-Apple-fruit-34914757-1600-1544.jpg
# 9/100 http://3.bp.blogspot.com/-UVKtYNveZn4/UHRSnSSvD7I/AAAAAAAABpg/cOFlpmQpIuo/s1600/the-seduction-green-apples.jpg
# ...

# %%
#Verificamos que ahora exista la carpeta images
# !ls
# Out:
# beautiful_scraper.py  clean_images.py  LICENSE	  requirements.txt
# bing_scraper.py       images	       README.md

# %%
#Mostramos las carpetas creadas de cada busqueda
# !ls images
# Out:
# apple_fruit_green  oxxo  oxxo_edificio	oxxo_entrada

# %% [markdown]
# ## Paso 4: Comprimir y copiamos las imagenes a nuestro espacio del Drive

# %%
#Comprimimos las imagenes en el archivo images_web.zip
# !zip -r images_web.zip images
# Out:
#   adding: images/ (stored 0%)
#   adding: images/oxxo_edificio/ (stored 0%)
#   adding: images/oxxo_edificio/97.EB-EE4093.jpeg (deflated 0%)
#   adding: images/oxxo_edificio/6.oxxo+tepic1.jpg (deflated 0%)
#   adding: images/oxxo_edificio/32.asaltante-oxxo-escapa-del-edificio-fge-T-wA7FBR.jpeg (deflated 1%)
#   adding: images/oxxo_edificio/73.oxxeo-entrance-dropoff.jpg (deflated 0%)
#   adding: images/oxxo_edificio/18.oxxo2.jpg (deflated 26%)
#   adding: images/oxxo_edificio/90.galeria_9-495x400.jpg (deflated 1%)
#   adding: images/oxxo_edificio/10.oxxo-173546.jpg (deflated 0%)
#   adding: images/oxxo_edificio/77.44633662_kVkom0c70-1SwJkifr7mV8tv8_j7vq6lsZbdbUvfIMA.jpg (deflated 1%)
#   adding: images/oxxo_edificio/16.153609-14013455.jpg (deflated 0%)
#   adding: images/oxxo_edificio/79.lamp-oxxeo-06.jpg (deflated 1%)
#   adding: images/oxxo_edificio/94.oxxo.jpg (deflated 17%)
#   adding: images/oxxo_edificio/58.22835.jpg (deflated 0%)
# ...

# %%
#Copiamos el archivo images_web.zip a nuestro espacio del Drive 
# !cp images_web.zip "/content/drive/My Drive/YOLO/custom/data"
